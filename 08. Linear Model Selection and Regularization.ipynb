# %%
# imports and steup
# %matplotlib inline

import numpy as np
import pandas as pd

import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

pd.set_option('precision', 4)
pd.set_option('display.max_rows', 12)
pd.set_option('display.max_columns', 12)
pd.set_option('display.float_format', '{:20,.5f}'.format)

plt.style.use('seaborn')

# %%
wage = pd.read_csv('./Wage.csv', index_col=0)
wage.iloc[:, 2:10] = wage.iloc[:, 2:10].apply(pd.Categorical)

# %%
wage
# Out:
#         year  age      sex            maritl      race        education  \
# 231655  2006   18  1. Male  1. Never Married  1. White     1. < HS Grad
# 86582   2004   24  1. Male  1. Never Married  1. White  4. College Grad
# 161300  2003   45  1. Male        2. Married  1. White  3. Some College
# 155159  2003   43  1. Male        2. Married  3. Asian  4. College Grad
# 11443   2005   50  1. Male       4. Divorced  1. White       2. HS Grad
# ...      ...  ...      ...               ...       ...              ...
# 376816  2008   44  1. Male        2. Married  1. White  3. Some College
# 302281  2007   30  1. Male        2. Married  1. White       2. HS Grad
# 10033   2005   27  1. Male        2. Married  2. Black     1. < HS Grad
# 14375   2005   27  1. Male  1. Never Married  1. White  3. Some College
# 453557  2009   55  1. Male      5. Separated  1. White       2. HS Grad
#
#                     region        jobclass          health health_ins  \
# 231655  2. Middle Atlantic   1. Industrial       1. <=Good      2. No
# 86582   2. Middle Atlantic  2. Information  2. >=Very Good      2. No
# 161300  2. Middle Atlantic   1. Industrial       1. <=Good     1. Yes
# 155159  2. Middle Atlantic  2. Information  2. >=Very Good     1. Yes
# 11443   2. Middle Atlantic  2. Information       1. <=Good     1. Yes
# ...                    ...             ...             ...        ...
# 376816  2. Middle Atlantic   1. Industrial  2. >=Very Good     1. Yes
# 302281  2. Middle Atlantic   1. Industrial  2. >=Very Good      2. No
# 10033   2. Middle Atlantic   1. Industrial       1. <=Good      2. No
# 14375   2. Middle Atlantic   1. Industrial  2. >=Very Good     1. Yes
# 453557  2. Middle Atlantic   1. Industrial       1. <=Good     1. Yes
#
#                     logwage                 wage
# 231655              4.31806             75.04315
# 86582               4.25527             70.47602
# 161300              4.87506            130.98218
# 155159              5.04139            154.68529
# 11443               4.31806             75.04315
# ...                     ...                  ...
# 376816              5.04139            154.68529
# 302281              4.60206             99.68946
# 10033               4.19312             66.22941
# 14375               4.47712             87.98103
# 453557              4.50515             90.48191
#
# [3000 rows x 12 columns]

# %%
from sklearn.preprocessing import PolynomialFeatures

pol = PolynomialFeatures(degree=5, interaction_only=False, include_bias=False)
polf = pol.fit_transform(wage.loc[:, 'age'].values.reshape(-1, 1))

wage['age_2'] = polf[:,1]
wage['age_3'] = polf[:,2]
wage['age_4'] = polf[:,3]
wage['age_5'] = polf[:,4]

# %%
wage
# Out:
#         year  age      sex            maritl      race        education  ...  \
# 231655  2006   18  1. Male  1. Never Married  1. White     1. < HS Grad  ...
# 86582   2004   24  1. Male  1. Never Married  1. White  4. College Grad  ...
# 161300  2003   45  1. Male        2. Married  1. White  3. Some College  ...
# 155159  2003   43  1. Male        2. Married  3. Asian  4. College Grad  ...
# 11443   2005   50  1. Male       4. Divorced  1. White       2. HS Grad  ...
# ...      ...  ...      ...               ...       ...              ...  ...
# 376816  2008   44  1. Male        2. Married  1. White  3. Some College  ...
# 302281  2007   30  1. Male        2. Married  1. White       2. HS Grad  ...
# 10033   2005   27  1. Male        2. Married  2. Black     1. < HS Grad  ...
# 14375   2005   27  1. Male  1. Never Married  1. White  3. Some College  ...
# 453557  2009   55  1. Male      5. Separated  1. White       2. HS Grad  ...
#
#                     logwage                 wage                age_2  \
# 231655              4.31806             75.04315            324.00000
# 86582               4.25527             70.47602            576.00000
# 161300              4.87506            130.98218          2,025.00000
# 155159              5.04139            154.68529          1,849.00000
# 11443               4.31806             75.04315          2,500.00000
# ...                     ...                  ...                  ...
# 376816              5.04139            154.68529          1,936.00000
# 302281              4.60206             99.68946            900.00000
# 10033               4.19312             66.22941            729.00000
# 14375               4.47712             87.98103            729.00000
# 453557              4.50515             90.48191          3,025.00000
#
#                       age_3                age_4                age_5
# 231655          5,832.00000        104,976.00000      1,889,568.00000
# 86582          13,824.00000        331,776.00000      7,962,624.00000
# 161300         91,125.00000      4,100,625.00000    184,528,125.00000
# 155159         79,507.00000      3,418,801.00000    147,008,443.00000
# 11443         125,000.00000      6,250,000.00000    312,500,000.00000
# ...                     ...                  ...                  ...
# 376816         85,184.00000      3,748,096.00000    164,916,224.00000
# 302281         27,000.00000        810,000.00000     24,300,000.00000
# 10033          19,683.00000        531,441.00000     14,348,907.00000
# 14375          19,683.00000        531,441.00000     14,348,907.00000
# 453557        166,375.00000      9,150,625.00000    503,284,375.00000
#
# [3000 rows x 16 columns]

# %%
(wage.wage > 250)
# Out:
# 231655    False
# 86582     False
# 161300    False
# 155159    False
# 11443     False
#           ...
# 376816    False
# 302281    False
# 10033     False
# 14375     False
# 453557    False
# Name: wage, Length: 3000, dtype: bool

# %%
(wage.wage > 250).map({True:1, False: 0})
# Out:
# 231655    0
# 86582     0
# 161300    0
# 155159    0
# 11443     0
#          ..
# 376816    0
# 302281    0
# 10033     0
# 14375     0
# 453557    0
# Name: wage, Length: 3000, dtype: int64

# %%
wage['wage_250'] = (wage.wage > 250).map({True:1, False:0})

x = wage.loc[:, ['age', 'age_2', 'age_3', 'age_4']]
y = wage.wage

# %%
wage
# Out:
#         year  age      sex            maritl      race        education  ...  \
# 231655  2006   18  1. Male  1. Never Married  1. White     1. < HS Grad  ...
# 86582   2004   24  1. Male  1. Never Married  1. White  4. College Grad  ...
# 161300  2003   45  1. Male        2. Married  1. White  3. Some College  ...
# 155159  2003   43  1. Male        2. Married  3. Asian  4. College Grad  ...
# 11443   2005   50  1. Male       4. Divorced  1. White       2. HS Grad  ...
# ...      ...  ...      ...               ...       ...              ...  ...
# 376816  2008   44  1. Male        2. Married  1. White  3. Some College  ...
# 302281  2007   30  1. Male        2. Married  1. White       2. HS Grad  ...
# 10033   2005   27  1. Male        2. Married  2. Black     1. < HS Grad  ...
# 14375   2005   27  1. Male  1. Never Married  1. White  3. Some College  ...
# 453557  2009   55  1. Male      5. Separated  1. White       2. HS Grad  ...
#
#                        wage                age_2                age_3  \
# 231655             75.04315            324.00000          5,832.00000
# 86582              70.47602            576.00000         13,824.00000
# 161300            130.98218          2,025.00000         91,125.00000
# 155159            154.68529          1,849.00000         79,507.00000
# 11443              75.04315          2,500.00000        125,000.00000
# ...                     ...                  ...                  ...
# 376816            154.68529          1,936.00000         85,184.00000
# 302281             99.68946            900.00000         27,000.00000
# 10033              66.22941            729.00000         19,683.00000
# 14375              87.98103            729.00000         19,683.00000
# 453557             90.48191          3,025.00000        166,375.00000
#
#                       age_4                age_5  wage_250
# 231655        104,976.00000      1,889,568.00000         0
# 86582         331,776.00000      7,962,624.00000         0
# 161300      4,100,625.00000    184,528,125.00000         0
# 155159      3,418,801.00000    147,008,443.00000         0
# 11443       6,250,000.00000    312,500,000.00000         0
# ...                     ...                  ...       ...
# 376816      3,748,096.00000    164,916,224.00000         0
# 302281        810,000.00000     24,300,000.00000         0
# 10033         531,441.00000     14,348,907.00000         0
# 14375         531,441.00000     14,348,907.00000         0
# 453557      9,150,625.00000    503,284,375.00000         0
#
# [3000 rows x 17 columns]

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression(fit_intercept=True)
lin_reg.fit(x, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (-184.15417977420037,
#  array([ 2.12455205e+01, -5.63859313e-01,  6.81068771e-03, -3.20383037e-05]))

# %%
sns.regplot(x='age', y='wage', data=wage, order=4,
            scatter_kws={'alpha':0.2, 'color':'gray'});

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(fit_intercept=True, C=1e9)
log_reg.fit(x, wage.wage_250)

log_reg.intercept_, log_reg.coef_
# Out:
# (array([-5.6498836e-05]),
#  array([[-1.12834470e-03, -1.60767956e-02,  5.10936201e-04,
#          -4.28423013e-06]]))

# %%
from statsmodels.formula.api import glm

lr_sm = glm(formula='wage_250 ~ age + age_2 + age_3 + age_4',
           data=wage,
           family=sm.families.Binomial()).fit()

# %%
age_grid = np.arange(wage.age.min(), wage.age.max()).reshape(-1, 1)
x_test =  pd.DataFrame(PolynomialFeatures(4, include_bias=True).fit_transform(age_grid),
                      columns=['Intercept', 'age', 'age_2', 'age_3', 'age_4'])

log_reg_pred = lr_sm.predict(x_test)

plt.scatter(wage.age, wage.wage_250/5, marker='|', color='gray', alpha=0.5)
plt.plot(age_grid, log_reg_pred);

# %%
age_step, bins = pd.cut(wage.age, 4, retbins=True, right=True)
bins
# Out:
# array([17.938, 33.5  , 49.   , 64.5  , 80.   ])

# %%
wage_step= pd.concat([wage.age, age_step, wage.wage, wage.wage_250],
                    keys=['age', 'age_step', 'wage', 'wage_250'],
                    axis=1)
wage_step
# Out:
#         age        age_step                 wage  wage_250
# 231655   18  (17.938, 33.5]             75.04315         0
# 86582    24  (17.938, 33.5]             70.47602         0
# 161300   45    (33.5, 49.0]            130.98218         0
# 155159   43    (33.5, 49.0]            154.68529         0
# 11443    50    (49.0, 64.5]             75.04315         0
# ...     ...             ...                  ...       ...
# 376816   44    (33.5, 49.0]            154.68529         0
# 302281   30  (17.938, 33.5]             99.68946         0
# 10033    27  (17.938, 33.5]             66.22941         0
# 14375    27  (17.938, 33.5]             87.98103         0
# 453557   55    (49.0, 64.5]             90.48191         0
#
# [3000 rows x 4 columns]

# %%
x = pd.get_dummies(wage_step.age_step)
x = x.drop(x.columns[0], axis=1)
y = wage_step.wage

lr_step = LinearRegression(fit_intercept=True)
lr_step.fit(x, y)
lr_step.intercept_, lr_step.coef_
# Out:
# (94.15839203351904, array([24.05349138, 23.664559  ,  7.6405917 ]))

# %%
age_grid_bins = np.digitize(age_grid.ravel(), bins)
x_test = pd.get_dummies(age_grid_bins).drop(1, axis=1)
lin_pred = lr_step.predict(x_test)

plt.scatter(wage_step.age, wage.wage, marker='o', color='gray', alpha=0.5, facecolor='None')
plt.plot(age_grid, lin_pred);

# %%
from statsmodels.api import GLM

lr_sm = GLM(wage_step.wage_250, sm.add_constant(x),
            family=sm.families.Binomial()).fit()

log_pred = lr_sm.predict(sm.add_constant(x_test))

plt.scatter(wage_step.age, wage_step.wage_250/5, marker='|', color='gray', alpha=0.5)
plt.plot(age_grid, log_pred)
# Out:
# /Users/kangseunggu/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
from patsy import dmatrix

age_spline1 = dmatrix('bs(age, knots=(25,40,60), degree=3, include_intercept=False)',
                     data=wage,
                     return_type='dataframe')
age_spline1
# Out:
#                   Intercept  \
# 231655              1.00000
# 86582               1.00000
# 161300              1.00000
# 155159              1.00000
# 11443               1.00000
# ...                     ...
# 376816              1.00000
# 302281              1.00000
# 10033               1.00000
# 14375               1.00000
# 453557              1.00000
#
#         bs(age, knots=(25, 40, 60), degree=3, include_intercept=False)[0]  \
# 231655                                            0.00000
# 86582                                             0.55991
# 161300                                            0.00000
# 155159                                            0.00000
# 11443                                             0.00000
# ...                                                   ...
# 376816                                            0.00000
# 302281                                            0.13774
# 10033                                             0.30262
# 14375                                             0.30262
# 453557                                            0.00000
#
#         bs(age, knots=(25, 40, 60), degree=3, include_intercept=False)[1]  \
# 231655                                            0.00000
# 86582                                             0.40378
# 161300                                            0.11480
# 155159                                            0.16711
# 11443                                             0.03401
# ...                                                   ...
# 376816                                            0.13932
# 302281                                            0.62911
# 10033                                             0.58685
# 14375                                             0.58685
# 453557                                            0.00425
#
#         bs(age, knots=(25, 40, 60), degree=3, include_intercept=False)[2]  \
# 231655                                            0.00000
# 86582                                             0.03340
# 161300                                            0.61856
# 155159                                            0.63317
# 11443                                             0.50819
# ...                                                   ...
# 376816                                            0.62847
# 302281                                            0.22882
# 10033                                             0.11025
# 14375                                             0.11025
# 453557                                            0.34193
#
#         bs(age, knots=(25, 40, 60), degree=3, include_intercept=False)[3]  \
# 231655                                            0.00000
# 86582                                             0.00000
# 161300                                            0.26273
# 155159                                            0.19888
# 11443                                             0.42654
# ...                                                   ...
# 376816                                            0.23021
# 302281                                            0.00433
# 10033                                             0.00028
# 14375                                             0.00028
# 453557                                            0.54835
#
#         bs(age, knots=(25, 40, 60), degree=3, include_intercept=False)[4]  \
# 231655                                            0.00000
# 86582                                             0.00000
# 161300                                            0.00391
# 155159                                            0.00084
# 11443                                             0.03125
# ...                                                   ...
# 376816                                            0.00200
# 302281                                            0.00000
# 10033                                             0.00000
# 14375                                             0.00000
# 453557                                            0.10547
#
#         bs(age, knots=(25, 40, 60), degree=3, include_intercept=False)[5]
# 231655                                            0.00000
# 86582                                             0.00000
# 161300                                            0.00000
# 155159                                            0.00000
# 11443                                             0.00000
# ...                                                   ...
# 376816                                            0.00000
# 302281                                            0.00000
# 10033                                             0.00000
# 14375                                             0.00000
# 453557                                            0.00000
#
# [3000 rows x 7 columns]

# %%
age_grid_spline1 = dmatrix('bs(age_grid, knots=(25,40,60), degree=3, include_intercept=False)',
                          {'age_grid': age_grid},
                          return_type='dataframe')
age_grid_spline1
# Out:
#               Intercept  \
# 0               1.00000
# 1               1.00000
# 2               1.00000
# 3               1.00000
# 4               1.00000
# ..                  ...
# 57              1.00000
# 58              1.00000
# 59              1.00000
# 60              1.00000
# 61              1.00000
#
#     bs(age_grid, knots=(25, 40, 60), degree=3, include_intercept=False)[0]  \
# 0                                             0.00000
# 1                                             0.35200
# 2                                             0.56743
# 3                                             0.67110
# 4                                             0.68785
# ..                                                ...
# 57                                            0.00000
# 58                                            0.00000
# 59                                            0.00000
# 60                                            0.00000
# 61                                            0.00000
#
#     bs(age_grid, knots=(25, 40, 60), degree=3, include_intercept=False)[1]  \
# 0                                             0.00000
# 1                                             0.01810
# 2                                             0.06690
# 3                                             0.13813
# 4                                             0.22353
# ..                                                ...
# 57                                            0.00000
# 58                                            0.00000
# 59                                            0.00000
# 60                                            0.00000
# 61                                            0.00000
#
#     bs(age_grid, knots=(25, 40, 60), degree=3, include_intercept=False)[2]  \
# 0                                             0.00000
# 1                                             0.00015
# 2                                             0.00124
# 3                                             0.00417
# 4                                             0.00989
# ..                                                ...
# 57                                            0.00160
# 58                                            0.00067
# 59                                            0.00020
# 60                                            0.00002
# 61                                            0.00000
#
#     bs(age_grid, knots=(25, 40, 60), degree=3, include_intercept=False)[3]  \
# 0                                             0.00000
# 1                                             0.00000
# 2                                             0.00000
# 3                                             0.00000
# 4                                             0.00000
# ..                                                ...
# 57                                            0.05642
# 58                                            0.03291
# 59                                            0.01515
# 60                                            0.00392
# 61                                            0.00000
#
#     bs(age_grid, knots=(25, 40, 60), degree=3, include_intercept=False)[4]  \
# 0                                             0.00000
# 1                                             0.00000
# 2                                             0.00000
# 3                                             0.00000
# 4                                             0.00000
# ..                                                ...
# 57                                            0.44993
# 58                                            0.36924
# 59                                            0.26837
# 60                                            0.14579
# 61                                            0.00000
#
#     bs(age_grid, knots=(25, 40, 60), degree=3, include_intercept=False)[5]
# 0                                             0.00000
# 1                                             0.00000
# 2                                             0.00000
# 3                                             0.00000
# 4                                             0.00000
# ..                                                ...
# 57                                            0.49205
# 58                                            0.59717
# 59                                            0.71629
# 60                                            0.85027
# 61                                            1.00000
#
# [62 rows x 7 columns]

# %%
spline_reg1 = LinearRegression(fit_intercept=False)
spline_reg1.fit(age_spline1, wage.wage)

spline_pred1 = spline_reg1.predict(age_grid_spline1)

plt.scatter(wage.age, wage.wage, marker='o', color='gray', alpha=0.5, facecolor='None')
plt.plot(age_grid, spline_pred1);

# %%
age_spline2 = dmatrix('bs(age, df=6, include_intercept=False)',
                     data=wage,
                     return_type='dataframe')

age_grid_spline2 = dmatrix('bs(age_grid, df=6, include_intercept=False)',
                          {'age_grid':age_grid},
                          return_type='dataframe')

spline_reg2 = LinearRegression(fit_intercept=False)
spline_reg2.fit(age_spline2, wage.wage)

spline_pred2 = spline_reg2.predict(age_grid_spline2)

plt.scatter(wage.age, wage.wage, marker='o', color='gray', alpha=0.5, facecolor='None')
plt.plot(age_grid, spline_pred2)

# %%
age_spline3 = dmatrix('cr(age, df=4)',
                     data=wage,
                     return_type='dataframe')

age_grid_spline3 = dmatrix('cr(age_grid, df=4)',
                          {'age_grid': age_grid},
                          return_type='dataframe')

spline_reg3 = LinearRegression(fit_intercept=False)
spline_reg3.fit(age_spline3, wage.wage)

spline_pred3 = spline_reg3.predict(age_grid_spline3)


plt.scatter(wage.age, wage.wage, marker='o', color='gray', alpha=0.5, facecolor='None')
plt.plot(age_grid, spline_pred3)

# %%
year_spl = dmatrix('cr(year, df=4)',
                  data=wage,
                  return_type='dataframe').drop('Intercept', axis=1)

age_spl = dmatrix('cr(year, df=5)',
                  data=wage,
                  return_type='dataframe').drop('Intercept', axis=1)

edu_gam = pd.get_dummies(wage.education).iloc[:, 1:]

wage_gam = pd.concat([wage.wage, year_spl, age_spl, edu_gam], axis=1)

x = wage_gam.iloc[:, 1:14]
y = wage_gam.wage

gam = LinearRegression(fit_intercept=True)
gam.fit(x, y)

gam.intercept_, gam.coef_
# Out:
# (-84085667428273.64,
#  array([ 1.89339665e+14,  1.24649756e+14,  5.99598460e+13, -4.73006369e+12,
#         -1.05253998e+14, -5.67365656e+13, -8.21913335e+12,  4.02982989e+13,
#          8.88157311e+13,  1.16091372e+01,  2.36023898e+01,  4.03068300e+01,
#          6.66269073e+01]))
